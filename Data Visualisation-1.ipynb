# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
#creating a random dataframe
df = pd.DataFrame(np.random.randn(500), index = pd.date_range('2019-06-07', periods = 500), columns=['VALUES'])
#crating timeseries
ts = pd.Series(np.random.randn(500), index = pd.date_range('2019-06-07', periods = 500))
df.head()
# Out:
#               VALUES
# 2019-06-07  0.282949
# 2019-06-08  0.491602
# 2019-06-09 -0.635380
# 2019-06-10 -0.796778
# 2019-06-11  1.090649

# %%
df['VALUES'] = df['VALUES'].cumsum()
df.head()
# Out:
#               VALUES
# 2019-06-07  0.282949
# 2019-06-08  0.774551
# 2019-06-09  0.139171
# 2019-06-10 -0.657607
# 2019-06-11  0.433043

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    1.140943
# 2019-06-08    0.001140
# 2019-06-09   -0.734184
# 2019-06-10   -1.084027
# 2019-06-11   -1.165498
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(8,8))

# %%
plt.plot(ts)

# %%
a=df.plot()
a.set_xlabel("Months")
a.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
#loading dataset from seaborn
iris = sns.load_dataset('iris')
iris.head(8)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
ax = iris.plot(figsize=(16,10), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar', figsize=(16,10))

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.415187 -0.826807 -0.149059  0.385504
# 1  0.216308  0.609197  1.247504 -2.065039
# 2  0.477132  1.488844  1.945324 -0.609931
# 3 -0.651924  1.469944  1.093557  1.865343
# 4 -0.905978  1.273539 -0.481161 -0.383421
# 5 -0.161491  1.969895 -1.037331  0.524466
# 6  0.225125 -1.553081 -1.019690  0.136215
# 7  1.050459 -0.383538 -0.116287 -0.124540
# 8  0.481990 -0.199991 -0.581572  1.072357
# 9 -1.289876  0.416014 -0.068816 -1.367067

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
#diff() method returns a DataFrame with the difference between the values for each row and, by default, the previous row
iris['sepal_width'].diff().head(10)
# Out:
# 0    NaN
# 1   -0.5
# 2    0.2
# 3   -0.1
# 4    0.5
# 5    0.3
# 6   -0.5
# 7    0.0
# 8   -0.5
# 9    0.2
# Name: sepal_width, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A40686E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A40998080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A409BF438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A409E59B0>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A423B0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A42503710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A4252AB70>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (30, 30), fontsize = 20, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A425B7828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A426D0898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A42869BA8>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (12,12), diagonal='kde', color = 'g')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (12, 10), logy = True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A47053C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A44B2ED30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A44A75B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024A43A4BA58>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
